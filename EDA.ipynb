# %%
from Datapreparation import *
from satellite_eda import *
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
satellite_data = {
    "jason3": ("./orbital_elements/Jason-3.csv", "./manoeuvres/ja3man.txt"),
    "SRL": ("./orbital_elements/SARAL.csv", "./manoeuvres/srlman.txt"),
    "TOP": ("./orbital_elements/TOPEX.csv", "./manoeuvres/topman.txt"),
    "fengyunD": ("./orbital_elements/Fengyun-2D.csv", "./manoeuvres/manFY2D.txt.FY"),
    "fengyunE": ("./orbital_elements/Fengyun-2E.csv", "./manoeuvres/manFY2E.txt.FY"),
    "SEN3A": ("./orbital_elements/Sentinel-3A.csv", "./manoeuvres/s3aman.txt")
}

# %%
for sate, path in satellite_data.items():
    sate = Satellite(path[0], path[1])
    print(sate.df_orbit.info())
    print(sate.df_man.info())
    print("The number of total manoeuvres:", len(sate.df_man))
    print("The ratio between true manoeuvres and total number of observations to measure imbalance:", len(sate.df_man)/len(sate.df_orbit))
    eda = SatelliteEDA(sate)
    eda.col_with_man()
# Out:
# Loading dataset JASO3 Ready.
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2410 entries, 2016-01-31 to 2022-10-03
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eccentricity         2410 non-null   float64
#  1   argument of perigee  2410 non-null   float64
#  2   inclination          2410 non-null   float64
#  3   mean anomaly         2410 non-null   float64
#  4   Brouwer mean motion  2410 non-null   float64
#  5   right ascension      2410 non-null   float64
# dtypes: float64(6)
# memory usage: 131.8 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            43 non-null     object
#  1   manoeuvre_date  43 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 820.0+ bytes
# None
# The number of total manoeuvres: 43
# The ratio between true manoeuvres and total number of observations to measure imbalance: 0.01784232365145228
# Loading dataset SARAL Ready.
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3290 entries, 2013-03-10 to 2022-09-14
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eccentricity         3290 non-null   float64
#  1   argument of perigee  3290 non-null   float64
#  2   inclination          3290 non-null   float64
#  3   mean anomaly         3290 non-null   float64
#  4   Brouwer mean motion  3290 non-null   float64
#  5   right ascension      3290 non-null   float64
# dtypes: float64(6)
# memory usage: 179.9 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            62 non-null     object
#  1   manoeuvre_date  62 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.1+ KB
# None
# The number of total manoeuvres: 62
# The ratio between true manoeuvres and total number of observations to measure imbalance: 0.01884498480243161
# Loading dataset TOPEX Ready.
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4134 entries, 1992-08-27 to 1999-12-31
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eccentricity         4134 non-null   float64
#  1   argument of perigee  4134 non-null   float64
#  2   inclination          4134 non-null   float64
#  3   mean anomaly         4134 non-null   float64
#  4   Brouwer mean motion  4134 non-null   float64
#  5   right ascension      4134 non-null   float64
# dtypes: float64(6)
# memory usage: 226.1 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            43 non-null     object
#  1   manoeuvre_date  43 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 820.0+ bytes
# None
# The number of total manoeuvres: 43
# The ratio between true manoeuvres and total number of observations to measure imbalance: 0.010401548137397194
# Loading dataset FY2D Ready.
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1187 entries, 2011-01-27 to 2015-04-16
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eccentricity         1187 non-null   float64
#  1   argument of perigee  1187 non-null   float64
#  2   inclination          1187 non-null   float64
#  3   mean anomaly         1187 non-null   float64
#  4   Brouwer mean motion  1187 non-null   float64
#  5   right ascension      1187 non-null   float64
# dtypes: float64(6)
# memory usage: 64.9 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 21 to 0
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            22 non-null     object
#  1   manoeuvre_date  22 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 528.0+ bytes
# None
# The number of total manoeuvres: 22
# The ratio between true manoeuvres and total number of observations to measure imbalance: 0.018534119629317607
# Loading dataset FY2E Ready.
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2375 entries, 2011-03-13 to 2018-10-21
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eccentricity         2375 non-null   float64
#  1   argument of perigee  2375 non-null   float64
#  2   inclination          2375 non-null   float64
#  3   mean anomaly         2375 non-null   float64
#  4   Brouwer mean motion  2375 non-null   float64
#  5   right ascension      2375 non-null   float64
# dtypes: float64(6)
# memory usage: 129.9 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 47 to 0
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            48 non-null     object
#  1   manoeuvre_date  48 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.1+ KB
# None
# The number of total manoeuvres: 48
# The ratio between true manoeuvres and total number of observations to measure imbalance: 0.020210526315789474
# Loading dataset SEN3A Ready.
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2385 entries, 2016-03-04 to 2022-09-29
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eccentricity         2385 non-null   float64
#  1   argument of perigee  2385 non-null   float64
#  2   inclination          2385 non-null   float64
#  3   mean anomaly         2385 non-null   float64
#  4   Brouwer mean motion  2385 non-null   float64
#  5   right ascension      2385 non-null   float64
# dtypes: float64(6)
# memory usage: 130.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            64 non-null     object
#  1   manoeuvre_date  64 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.1+ KB
# None
# The number of total manoeuvres: 64
# The ratio between true manoeuvres and total number of observations to measure imbalance: 0.026834381551362682

# %% [markdown]
# # FY2D

# %%
FY2D = Satellite("./orbital_elements/Fengyun-2D.csv", "./manoeuvres/manFY2D.txt.FY")
eda = SatelliteEDA(FY2D)
eda.col_with_man(start_date = "2012-01-01", end_date = "2013-01-01")
# Out:
# Loading dataset FY2D Ready.

# %% [markdown]
# # FY2E

# %%
FY2E = Satellite("./orbital_elements/Fengyun-2E.csv", "./manoeuvres/manFY2E.txt.FY")
eda = SatelliteEDA(FY2E)
eda.col_with_man(start_date = "2015-01-01", end_date = "2016-01-01")
eda.col_with_man(start_date = "2012-01-01", end_date = "2013-01-01")
# Out:
# Loading dataset FY2E Ready.

# %% [markdown]
# # SEN3A

# %%
S3 = Satellite("./orbital_elements/Sentinel-3A.csv", "./manoeuvres/s3aman.txt")
eda = SatelliteEDA(S3)
eda.col_with_man(start_date = "2019-01-01", end_date = "2020-01-01")
# Out:
# Loading dataset SEN3A Ready.

# %% [markdown]
# # Jason 3

# %%
J3 = Satellite("./orbital_elements/Jason-3.csv", "./manoeuvres/ja3man.txt")
eda = SatelliteEDA(J3)
eda.col_with_man_trimmed(clip_value=0.1) # Trimmed the extreme values in Jason 3 Brouwer Mean Motion to +- 0.1
eda.col_with_man(start_date = "2018-01-01", end_date = "2019-01-01")

std_b = standardize(J3.df_orbit['Brouwer mean motion'])
sns.boxplot(std_b)
# Out:
# Loading dataset JASO3 Ready.
# <Axes: >

# %%
# Find outliers
import numpy as np
threshold = 3  
outliers = std_b[np.abs(std_b) > threshold]
outlier_indices = outliers.index
print(outlier_indices)
# Out:
# DatetimeIndex(['2016-01-31', '2016-02-04', '2016-02-05', '2016-02-06',
#                '2016-02-07', '2016-02-08', '2022-04-15', '2022-04-16',
#                '2022-04-17', '2022-04-18', '2022-04-19'],
#               dtype='datetime64[ns]', name='Time', freq=None)

# %%
eda.col_with_man(start_date = "2016-02-01", end_date = "2016-03-01")

# %% [markdown]
# # SARAL

# %%
SRL = Satellite("./orbital_elements/SARAL.csv", "./manoeuvres/srlman.txt")
eda = SatelliteEDA(SRL)
eda.col_with_man(start_date="2016-01-01", end_date = "2018-01-01")

eda.col_with_man(start_date="2015-01-01", end_date = "2016-01-01")

eda.col_with_man(start_date="2018-01-01", end_date = "2022-01-01")
# Out:
# Loading dataset SARAL Ready.

# %% [markdown]
# # TOP

# %%
TOP = Satellite("./orbital_elements/TOPEX.csv", "./manoeuvres/topman.txt")
eda = SatelliteEDA(TOP)
eda.col_with_man(start_date="2002-06-01", end_date="2002-11-01")
eda.col_with_man(start_date="2002-01-01", end_date="2002-07-01")
eda.col_with_man(start_date="1994-01-01", end_date = "1995-01-01")
# Out:
# Loading dataset TOPEX Ready.
